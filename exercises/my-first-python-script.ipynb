# %%
print('Hello World!')
print('Another text here :)')
# Out:
# Hello World!
# Another text here :)

# %%
# let create an error
print(hello)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # let create an error
# ----> 2 print(hello)
#
# NameError: name 'hello' is not defined

# %% [markdown]
# This is a normal text and not a code.
# We can use Markdown text as explanation
