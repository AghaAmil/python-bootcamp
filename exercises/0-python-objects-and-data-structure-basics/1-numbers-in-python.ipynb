# %%
# Addition
1+3
# Out:
# 4

# %%
# Subtraction
5 - 11
# Out:
# -6

# %%
# Multiplication
3 * 4
# Out:
# 12

# %%
# Division
121 / 11
# Out:
# 11.0

# %% [markdown]
# Interestingly the result of the division is a float number

# %%
# Floor Division
143 // 45
# Out:
# 3

# %%
# Modulus
143 % 45
# Out:
# 8

# %%
# Power
2 ** 5
# Out:
# 32

# %%
# Square root of numbers
81 ** 0.5
# Out:
# 9.0

# %%
# Operations order in Python
5 + 10 * 10 + 4
# Out:
# 109

# %%
# Change the operations order
(5 + 10) * (10 + 4)
# Out:
# 210
