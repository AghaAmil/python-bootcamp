# %%
a = 1

# %%
a
# Out:
# 1

# %%
a = 10

# %%
a
# Out:
# 10

# %%
a = a + a

# %%
a
# Out:
# 40

# %%
a
# Out:
# 40

# %%
type(a)
# Out:
# int

# %%
a = 30.5

# %%
type(a)
# Out:
# float

# %%
my_income = 100
tax_rate = 0.1

# %%
tax_calculation = my_income * tax_rate

# %%
tax_calculation
# Out:
# 10.0
